# %% [markdown]
# ### IMPORT PACKAGES & FUNCTIONS

# %%
import hdbscan
import random
from Recommendation_System_Location_Based_Pre_Work import df2_co_topcat
from Recommendation_System_Location_Based_Pre_Work import mapVisualize
from Recommendation_System_Location_Based_Pre_Work import addPredictedClusters
from Recommendation_System_Location_Based_Pre_Work import numOfClusters

# %%
df2_co_topcat.info() #5141 non-null entries
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5141 entries, 0 to 5140
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   uid         5141 non-null   object
#  1   category    5141 non-null   object
#  2   categoryid  5141 non-null   float64
#  3   merchant    5141 non-null   object
#  4   city        5141 non-null   object
#  5   latitude    5141 non-null   float64
#  6   longitude   5141 non-null   float64
# dtypes: float64(3), object(4)
# memory usage: 281.3+ KB

# %% [markdown]
# ### Current view of transactions on the map

# %%
mapVisualize(df2_co_topcat,"latitude","longitude",'category','Current_Transactions_Map_Over_CO') #Visualize clusters on the map
# Out:
# <div>
#
#
#             <div id="c5ff3c82-6712-4aee-bb33-5f3222a377df" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c5ff3c82-6712-4aee-bb33-5f3222a377df")) {
#                     Plotly.newPlot(
#                         'c5ff3c82-6712-4aee-bb33-5f3222a377df',
#                         [{"customdata": [["Restaurants/Dining", "Littleton", "chick-fil-a", 39.568909, -105.110031], ["Restaurants/Dining", "Greenwood Village", "the original pancake house", 39.59608, -104.88609], ["Restaurants/Dining", "Longmont", "chick-fil-a", 40.15203, -105.09626], ["Restaurants/Dining", "Longmont", "starbucks", 40.1891, -105.12987], ["Restaurants/Dining", "Fort Collins", "ku cha house of tea", 40.07206, -105.20091], ["Restaurants/Dining", "Castle Rock", "panda express", 39.41341, -104.85779], ["Restaurants/Dining", "Highlands Ranch", "noodles & company", 39.54809, -105.00194], ["Restaurants/Dining", "Sheridan", "andy's frozen custard", 39.6469, -105.0253], ["Restaurants/Dining", "Longmont", "jai thai", 40.15203, -105.09626], ["Restaurants/Dining", "Longmont", "jai thai", 40.15203, -105.09626], ["Restaurants/Dining", "Lafayette", "panang thai", 40.00163, -105.10196], ["Restaurants/Dining", "Denver", "brick oven pizza", 39.7392, -104.9903], ["Restaurants/Dining", "Longmont", "chick-fil-a", 40.15203, -105.09626], ["Restaurants/Dining", "Loveland", "asian cafe & grill", 40.407745, -105.05619], ["Restaurants/Dining", "Lafayette", "firehouse subs", 39.98665, -105.09742], ["Restaurants/Dining", "Lafayette", "firehouse subs", 39.98665, -105.09742], ["Restaurants/Dining", "Lafayette", "firehouse subs", 39.98665, -105.09742], ["Restaurants/Dining", "Lafayette", "firehouse subs", 39.98665, -105.09742], ["Restaurants/Dining", "Lafayette", "firehouse subs", 39.98665, -105.09742], ["Restaurants/Dining", "Lafayette", "firehouse subs", 39.98665, -105.09742], ["Restaurants/Dining", "Lafayette", "firehouse subs", 39.98665, -105.09742], ["Restaurants/Dining", "Lafayette", "firehouse subs", 39.98665, -105.09742], ["Restaurants/Dining", "Parker", "hickory house", 39.5101, -104.76533], ["Restaurants/Dining", "Highlands Ranch", "raising cane's", 39.54809, -105.00194], ["Restaurants/Dining", "Eaton", "five & hoek", 40.5194, -104.7025], ["Restaurants/Dining", "Denver", "which wich superior sandwiches", 39.67993, -104.94228], ["Restaurants/Dining", "Vail", "grappa fine wines", 39.631078, -106.417869], ["Restaurants/Dining", "Denver", "which wich superior sandwiches", 39.67993, -104.94228], ["Restaurants/Dining", "Monument", "chili's", 39.06348, -104.85442], ["Restaurants/Dining", "Castle Rock", "caribou coffee", 39.41341, -104.85779], ["Restaurants/Dining", "Highlands Ranch", "taco bell", 39.52607, -104.9417], ["Restaurants/Dining", "Englewood", "broken tee", 39.53611, -105.01408], ["Restaurants/Dining", "Lafayette", "sushi aji", 40.00163, -105.10196], ["Restaurants/Dining", "Lafayette", "sushi aji", 40.00163, -105.10196], ["Restaurants/Dining", "Lafayette", "sushi aji", 40.00163, -105.10196], ["Restaurants/Dining", "Lafayette", "sushi aji", 40.00163, -105.10196], ["Restaurants/Dining", "Lafayette", "sushi aji", 40.00163, -105.10196], ["Restaurants/Dining", "Lafayette", "sushi aji", 40.00163, -105.10196], ["Restaurants/Dining", "Lafayette", "sushi aji", 40.00163, -105.10196], ["Restaurants/Dining", "Lafayette", "sushi aji", 40.00163, -105.10196], ["Restaurants/Dining", "Lafayette", "sushi aji", 40.00163, -105.10196], ["Restaurants/Dining", "Lone Tree", "panera bread", 39.53481, -104.88388], ["Restaurants/Dining", "Longmont", "wendy's", 40.14819, -105.1315], ["Restaurants/Dining", "Denver", "kung fu tea", 39.7392, -104.9903], ["Restaurants/Dining", "Denver", "kung fu tea", 39.7392, -104.9903], ["Restaurants/Dining", "Englewood", "broken tee", 39.53611, -105.01408], ["Restaurants/Dining", "Vail", "grappa fine wines", 39.631078, -106.417869], ["Restaurants/Dining", "Vail", "vail brewing vail co card9815", 39.631078, -106.417869], ["Restaurants/Dining", "Denver", "7 hermits", 39.7392, -104.9903], ["Restaurants/Dining", "Denver", "7 hermits", 39.7392, -104.9903], ["Restaurants/Dining", "Vail", "delizioso", 39.631078, -106.417869], ["Restaurants/Dining", "Denver", "7 hermits", 39.7392, -104.9903], ["Restaurants/Dining", "Denver", "7 her ...

# %% [markdown]
# #### From above map, we can see that there are clearly "outliers" i.e. points that will not or should not be part of clusters. The clusters produced by the clustering algorithm should mark outliers as noise and seperate them from the island clusters with data points that are closest to each other.

# %% [markdown]
# ##############################################################################################################################

# %% [markdown]
# ## Clustering

# %% [markdown]
# ### 1.HDBScan

# %%
#Using lat and long to define clusters.
df_cluster=df2_co_topcat[['latitude','longitude']]

# %%
#create a clustering object
min_size=10
clusterer = hdbscan.HDBSCAN(min_cluster_size=min_size, prediction_data=True).fit(df_cluster)

# %%
# get the labels from the clusterer object
clusterer.labels_
unique_labels = set(clusterer.labels_)

# get the number of clusters
num_clusters = len(set(clusterer.labels_))
print('Total number of clusters formed with min_cluster_size of '+ str(min_size) + ': ' + str(num_clusters))
# Out:
# Total number of clusters formed with min_cluster_size of 10: 100

# %%
#Add new predicted cluster to the dataframe
df2_co_topcat=addPredictedClusters(df2_co_topcat,clusterer.labels_,'cluster')

# %%
# Distribution of data within each cluster
print(numOfClusters(df2_co_topcat,'cluster'))
# Out:
# cluster  -1    0    1    2    3    4    5    6    7    8   ...   89   90   91  \
# count    342   12   47   11   13   14   24   57   48   12  ...  236   12   20
#
# cluster   92   93   94   95   96   97   98
# count     46   16   69   76   15   16   14
#
# [1 rows x 100 columns]

# %%
#Visualize clusters on the map
mapVisualize(df2_co_topcat,"latitude","longitude",'cluster','HDBScan-lat-long-TopCat')
# Out:
# <div>
#
#
#             <div id="2a946438-3c55-4028-8ad4-0ec110ee13ba" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2a946438-3c55-4028-8ad4-0ec110ee13ba")) {
#                     Plotly.newPlot(
#                         '2a946438-3c55-4028-8ad4-0ec110ee13ba',
#                         [{"customdata": [["Restaurants/Dining", "Littleton", "chick-fil-a", 39.568909, -105.110031], ["Restaurants/Dining", "Greenwood Village", "the original pancake house", 39.59608, -104.88609], ["Restaurants/Dining", "Longmont", "chick-fil-a", 40.15203, -105.09626], ["Restaurants/Dining", "Longmont", "starbucks", 40.1891, -105.12987], ["Groceries", "Denver", "safeway", 39.6671, -104.91788], ["Groceries", "Denver", "king soopers", 39.70833, -104.93252], ["Groceries", "Fort Collins", "rocket fizz", 40.07206, -105.20091], ["Restaurants/Dining", "Fort Collins", "ku cha house of tea", 40.07206, -105.20091], ["Clothing/Shoes", "Longmont", "dsw", 40.15203, -105.09626], ["Groceries", "Niwot", "niwot liquor", 40.100818, -105.167939], ["Groceries", "Lafayette", "king soopers", 40.00163, -105.10196], ["Groceries", "Lafayette", "king soopers", 40.00163, -105.10196], ["Groceries", "Lafayette", "king soopers", 40.00163, -105.10196], ["Restaurants/Dining", "Castle Rock", "panda express", 39.41341, -104.85779], ["Restaurants/Dining", "Highlands Ranch", "noodles & company", 39.54809, -105.00194], ["Groceries", "Glendale", "king soopers", 39.53611, -105.01408], ["Groceries", "Monument", "kum & go", 39.092593, -104.852171], ["Restaurants/Dining", "Sheridan", "andy's frozen custard", 39.6469, -105.0253], ["Home Improvement", "Glendale", "the home depot", 39.70111, -104.93812], ["General Merchandise", "Denver", "big 5 sporting goods", 39.690565, -104.940142], ["Groceries", "Denver", "mcnally's liquors", 39.6671, -104.91788], ["Groceries", "Denver", "grapevine wine & liquor", 39.6671, -104.91788], ["General Merchandise", "Westminster", "walmart", 39.8891, -105.08214], ["Healthcare/Medical", "Longmont", "walgreens", 40.15487, -105.08887], ["General Merchandise", "Longmont", "target", 40.15721, -105.13277], ["Restaurants/Dining", "Longmont", "jai thai", 40.15203, -105.09626], ["General Merchandise", "Longmont", "target", 40.15721, -105.13277], ["Restaurants/Dining", "Longmont", "jai thai", 40.15203, -105.09626], ["Restaurants/Dining", "Lafayette", "panang thai", 40.00163, -105.10196], ["Restaurants/Dining", "Denver", "brick oven pizza", 39.7392, -104.9903], ["Restaurants/Dining", "Longmont", "chick-fil-a", 40.15203, -105.09626], ["Restaurants/Dining", "Loveland", "asian cafe & grill", 40.407745, -105.05619], ["Healthcare/Medical", "Longmont", "walgreens", 40.15487, -105.08887], ["General Merchandise", "Longmont", "family dollar", 40.17486, -105.10443], ["General Merchandise", "Longmont", "family dollar", 40.17486, -105.10443], ["Groceries", "Niwot", "niwot liquor", 40.100818, -105.167939], ["Groceries", "Niwot", "niwot liquor", 40.100818, -105.167939], ["General Merchandise", "Castle Rock", "target", 39.41341, -104.85779], ["General Merchandise", "Castle Rock", "walmart", 39.3983, -104.85556], ["Restaurants/Dining", "Lafayette", "firehouse subs", 39.98665, -105.09742], ["Restaurants/Dining", "Lafayette", "firehouse subs", 39.98665, -105.09742], ["Restaurants/Dining", "Lafayette", "firehouse subs", 39.98665, -105.09742], ["Restaurants/Dining", "Lafayette", "firehouse subs", 39.98665, -105.09742], ["Restaurants/Dining", "Lafayette", "firehouse subs", 39.98665, -105.09742], ["Restaurants/Dining", "Lafayette", "firehouse subs", 39.98665, -105.09742], ["Restaurants/Dining", "Lafayette", "firehouse subs", 39.98665, -105.09742], ["Restaurants/Dining", "Lafayette", "firehouse subs", 39.98665, -105.09742], ["Groceries", "Glendale", "king soopers", 39.53611, -105.01408], ["Groceries", "Glendale", "king soopers", 39.53611, -105.01408], ["Home Improvement", "Longmont", "lowe's", 40.1525, -105.08631], ["Home Improvement", "Longmont", "lowe's", 40.1525, -105.08631], ["General Merchandise", "Parker", "sman's warehouse", 39.5101, -104.76533], ["General Merchandise", "Parker", "sman's warehouse", 39.5101, -104.76533], ["Groceries", "Monument", "loop liquors", 39.092593, -104.852171], ["Restaurants/Dining", "Parker", "hickory house", 39.5101, -104. ...

# %% [markdown]
# ### HDBSCAN and min_cluster_size
# 1. The value of min_cluster_size is the key in building the location based recomm engine. After experimenting with small values (5-10), there are greater number of clusters but the noise (i.e. points that are not part of any clusters) is lower between 234-342.
#
# 2. With larger numbers for min_cluster_size (12-20) there are lesser number of clusters but the noise is also very high (440-615)
#
# 3. In order to make majority of the transaction data part of the clusters I went with min_cluster_size= 10. In doing so a few of the data points that were close but not 10 in number, were tagged as noise. However, majority of the data is part of some cluster.
# #### min_cluster_size=10, noise(cluster -1) = 342

# %% [markdown]
# ### Recommendation Engine Code

# %% [markdown]
# 1. Create a dataframe (recomm_df) from df2_co_topcat that contains merchants per tagged clusters and the number of transactions(popularity criteria) per merchant. The most popular merchants per cluster are on top of the recomm_df dataframe.
# It also contains the latitude/longitude information and city the recommended merchant is in.

# %%
recomm_df = df2_co_topcat.copy()
recomm_df = (recomm_df.groupby(['cluster', 'merchant']).agg({'latitude' : 'first',
                                                  'longitude' : 'first',
                                                  'city' : 'first',
                                                  'category' : 'first',
                                                  'cluster' : 'count'})
          .rename({'cluster' : 'cluster_count'},axis=1).reset_index()
          .sort_values(['cluster', 'cluster_count'], ascending = [True, False])
          .drop('cluster_count', axis=1))
#recomm_df.sample(5)

# %% [markdown]
# 2. Recommendation engine will first use method of hdbscan called 'approximate_predict' to predict the cluster of the given point (lat,long).
# 3. If the predicted cluser is -1 (noise), no merchant will be recommended.
# 4. It will then match the predicted cluster to the 'cluster' column of recomm_df.
# 5. Top 5 merchants based on popularity of the merchants are then displayed. The display contains the name, city, lat/long of the recommended merchants.

# %%
# Recommendation Engine Code:

def recommend_co_merchants_hdb(df,lat,long,city,merchant):
    # Predict the cluster for longitude and latitude provided
    test_labels, strengths = hdbscan.approximate_predict(clusterer, [[lat,long]])
    predicted_cluster=test_labels[0]
    print('Predicted cluster for this lat/long combination is: '  + str(predicted_cluster))
    print("_______________________________________________________________________________")
      # Get the best merchant in this cluster
    if predicted_cluster==-1:
        return ('No merchants close by')
    else:
        pop_merch_recomm_df=(df[df['cluster']==predicted_cluster].iloc[0:5][['merchant','city','latitude','longitude']])
        pop_merch_recomm_df=pop_merch_recomm_df.reset_index(drop=True)
        mask = (pop_merch_recomm_df.merchant==merchant) & (pop_merch_recomm_df.latitude==lat) & (pop_merch_recomm_df.longitude==long)
        print ('Since you are currently in '+ city.capitalize() + ' ' + 'at ' + merchant.capitalize() + ', how about you visit these merchants around this area? ')
        return pop_merch_recomm_df[~mask]

# %% [markdown]
# ### Test 1:

# %% [markdown]
# #### 1. Select a random row in df2_co_topcat dataframe and extract the lat, long and city information.

# %%
test_index=df2_co_topcat.sample(random_state=42).index.tolist()
test_index[0]
test_lat=df2_co_topcat.iloc[test_index[0]]['latitude']
test_long=df2_co_topcat.iloc[test_index[0]]['longitude']
test_city=df2_co_topcat.iloc[test_index[0]]['city']
test_merchant=df2_co_topcat.iloc[test_index[0]]['merchant']
test_lat, test_long, test_city, test_merchant
# Out:
# (40.016358, -105.130597, 'Lafayette', 'conoco gas station')

# %% [markdown]
# #### 2.  Provide the collected informaiton to the 'recommend_co_merchants_hdb' func

# %%
recommend_co_merchants_hdb(recomm_df,test_lat,test_long,test_city,test_merchant)
# Out:
# Predicted cluster for this lat/long combination is: 20
# _______________________________________________________________________________
# Since you are currently in Lafayette at Conoco gas station, how about you visit these merchants around this area?
#       merchant       city   latitude   longitude
# 0  smashburger  Lafayette  40.013218 -105.131553

# %% [markdown]
# ###########################################################################################################################

# %% [markdown]
# ### Test 2:

# %% [markdown]
# #### 1. Select a random row in df2_co_topcat dataframe and extract the lat, long and city information

# %%
test_index=df2_co_topcat.sample(random_state=10).index.tolist()
test_index[0]
test_lat=df2_co_topcat.iloc[test_index[0]]['latitude']
test_long=df2_co_topcat.iloc[test_index[0]]['longitude']
test_city=df2_co_topcat.iloc[test_index[0]]['city']
test_merchant=df2_co_topcat.iloc[test_index[0]]['merchant']
test_lat, test_long, test_city, test_merchant
# Out:
# (40.00163, -105.10196, 'Lafayette', 'king soopers')

# %% [markdown]
# #### 2.  Provide the collected informaiton to the 'recommend_co_merchants_hdb' func

# %%
recommend_co_merchants_hdb(recomm_df,test_lat,test_long,test_city,test_merchant)
# Out:
# Predicted cluster for this lat/long combination is: 44
# _______________________________________________________________________________
# Since you are currently in Lafayette at King soopers, how about you visit these merchants around this area?
#              merchant       city  latitude  longitude
# 1             walmart  Lafayette  40.00163 -105.10196
# 2          otis craft  Lafayette  40.00163 -105.10196
# 3  morning glory cafe  Lafayette  40.00163 -105.10196
# 4     natural grocers  Lafayette  40.00163 -105.10196
